# %%
import requests
from secret import FMP_API_TOKEN
BASE_URL='https://financialmodelingprep.com/stable'
symbol='AAPL'

# %% [markdown]
# ### Company Profile data

# %%
url = f'{BASE_URL}/profile?symbol={symbol}&apikey={FMP_API_TOKEN}'
data = requests.get(url).json()
data
# Out:
# [{'symbol': 'AAPL',
#   'price': 238.35,
#   'marketCap': 3580517535000,
#   'beta': 1.178,
#   'lastDividend': 1,
#   'range': '164.08-260.1',
#   'change': 3.02,
#   'changePercentage': 1.2833,
#   'volume': 7036693,
#   'averageVolume': 51386263,
#   'companyName': 'Apple Inc.',
#   'currency': 'USD',
#   'cik': '0000320193',
#   'isin': 'US0378331005',
#   'cusip': '037833100',
#   'exchangeFullName': 'NASDAQ Global Select',
#   'exchange': 'NASDAQ',
#   'industry': 'Consumer Electronics',
#   'website': 'https://www.apple.com',
# ...

# %% [markdown]
# ### Financial estimates: Revenue, earnings per share (EPS), and other key financial metrics

# %%
url = f'{BASE_URL}/analyst-estimates?symbol={symbol}&apikey={FMP_API_TOKEN}'
data = requests.get(url).json()
data

# %% [markdown]
# ### Ratings (snapshot)

# %%
url = f'{BASE_URL}/ratings-snapshot?symbol={symbol}&apikey={FMP_API_TOKEN}'
data = requests.get(url).json()
data
# Out:
# [{'symbol': 'AAPL',
#   'rating': 'B',
#   'overallScore': 3,
#   'discountedCashFlowScore': 3,
#   'returnOnEquityScore': 5,
#   'returnOnAssetsScore': 5,
#   'debtToEquityScore': 1,
#   'priceToEarningsScore': 2,
#   'priceToBookScore': 1}]

# %% [markdown]
# ### Ratings (historical)

# %%
url = f'{BASE_URL}/ratings-historical?symbol={symbol}&apikey={FMP_API_TOKEN}'
data = requests.get(url).json()
data
# Out:
# [{'symbol': 'AAPL',
#   'date': '2025-03-06',
#   'rating': 'B',
#   'overallScore': 3,
#   'discountedCashFlowScore': 3,
#   'returnOnEquityScore': 5,
#   'returnOnAssetsScore': 5,
#   'debtToEquityScore': 1,
#   'priceToEarningsScore': 2,
#   'priceToBookScore': 1}]

# %% [markdown]
# ### IPOs calendar

# %%
url = f'{BASE_URL}/ipos-calendar?&apikey={FMP_API_TOKEN}'
data = requests.get(url).json()
data
